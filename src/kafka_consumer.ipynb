# %%
from kafka import KafkaConsumer, KafkaProducer
from time import sleep
import json
from pyspark.sql import SparkSession
import requests

# %%
print('a')
# Out:
# a

# %%
consumer = KafkaConsumer('crypto_topic',bootstrap_servers=['ec2-3-82-8-178.compute-1.amazonaws.com:9092'],consumer_timeout_ms=20000, auto_offset_reset='earliest',value_deserializer= lambda x:json.loads(x.decode('utf-8')))

# %%
for c in consumer:
    print(c.value)
# Out:
# {'heaaaallo':'newww'}
# {'heaaaallo':'newww'}
# {'heaaaallo':'newww'}
# ...
